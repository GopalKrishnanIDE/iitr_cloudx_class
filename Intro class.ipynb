# %% [markdown]
# # Base 6 Number system
# 0,
# 1,
# 2,
# 3,
# 4,
# 5,
# 10,
# 11,
# 12,
# 13,
# 14,
# 15,
# 20,
# 21,
# 22,
# 23,
# 24,
# 25,
# 30,
# 31,
# 32,
# 33,
# 34,
# 35,
# 40

# %% [markdown]
# ![WhatsApp%20Image%202025-07-05%20at%2022.08.19_4758c883.jpg](attachment:WhatsApp%20Image%202025-07-05%20at%2022.08.19_4758c883.jpg)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Base 10 to Base 6

# %%
#base 10 to base 6 conversion
base10num = int(input("Please enter number in base 10 for conversion to Base 6 :")) 
#Formula to convert base 10 to base 6, first digit = 1000%6 =4 second digit = (1000//6) %6 =166%6 =4
#Third digit (166//6)%6=27%6 =3 Fourth digit 27//6 =4%6 = 4 . 4344
originalbase10 = base10num
mult = 1
result = 0
# Out:
# Please enter number in base 10 for conversion to Base 6 :19

# %%
while base10num >0:    
    rem = base10num%6
    result = result + (rem*mult)
    base10num = base10num//6
    mult = mult*10
    print(rem,result,base10num)
print(f"Conversion of Base10num {originalbase10} to Base6num is :",result)
# Out:
# 1 1 3
# 3 31 0
# Conversion of Base10num 19 to Base6num is : 31

# %% [markdown]
# # Base 6 to Base 10

# %%
#base 6 to base 10 conversion
base6num = int(input("Please enter nunmner in base 6 for conversion to Base 10 :"))
# 4344 = 4*1 + 6*4 + 6*6*3 + 6*6*6*4 =1000
originalbase6 = base6num
multbase10=1
resultbase10=0
# Out:
# Please enter nunmner in base 6 for conversion to Base 10 :1000

# %%
while base6num >0:    
    rem6 = base6num%10
    resultbase10 = resultbase10 + (rem6*multbase10)
    base6num = base6num//10
    multbase10 = multbase10*6
    print(rem6,resultbase10,base6num)
print(f"Conversion of Base6 num {originalbase6} to Base10num is :",resultbase10)
# Out:
# 0 0 100
# 0 0 10
# 0 0 1
# 1 216 0
# Conversion of Base6 num 1000 to Base10num is : 216

# %% [markdown]
# # Base M to Base N

# %%
#Base M to Base 10 to Base N
#Ask the user for the Base 3 to 9 (above 10, string is involved so to keep it simple, base is kept inside 10)
baseM = int(input("Please input the Base (3 to 9) for which you want to convert the number from :"))
baseN = int(input("please input the Base (3 to 9) to which you want to convert to :"))
baseMnum = int(input(f" Base {baseM} number :"))
originalbaseMnum = baseMnum
# Out:
# Please input the Base (3 to 9) for which you want to convert the number from :3
# please input the Base (3 to 9) to which you want to convert to :6
#  Base 3 number :112

# %%
#converting Base m number to Base 10 number
multbase10=1
resultbase10=0
while baseMnum >0:    
    remM = baseMnum%10
    resultbase10 = resultbase10 + (remM*multbase10)
    baseMnum = baseMnum//10
    multbase10 = multbase10*baseM
    print(remM,resultbase10,baseMnum)
print(f"Conversion of Base {baseM} num {originalbaseMnum} to Base 10 num is :",resultbase10)

print("-----------------------------------------------------------------------------------")
#convertion Base 10 to Base n
originalbase10num = resultbase10
multbaseN = 1
resultbaseN = 0

while resultbase10 >0:    
    remN = resultbase10%baseN
    resultbaseN = resultbaseN + (remN*multbaseN)
    resultbase10 = resultbase10//baseN
    multbaseN = multbaseN*10
    print(remN,resultbaseN,resultbase10)
print(f"Conversion of Base10num {originalbase10num} to Base {baseN} num is :",resultbaseN)
print(f"Conversion of Base {baseM} {originalbaseMnum} to Base {baseN} num is :",resultbaseN)
# Out:
# 2 2 11
# 1 5 1
# 1 14 0
# Conversion of Base 3 num 112 to Base 10 num is : 14
# -----------------------------------------------------------------------------------
# 2 2 2
# 2 22 0
# Conversion of Base10num 14 to Base 6 num is : 22
# Conversion of Base 3 112 to Base 6 num is : 22

# %%
# Out:
#   File "<ipython-input-15-a914d8dae6d9>", line 1
#     1a%5
#      ^
# SyntaxError: invalid syntax

# %%
def myinterest(p,r,t):
    interest = p*r*t/100
    return interest

# %%
myinterest (100,10,20)
# Out:
# 200.0

# %%
principle = 100
result = myinterest(principle,10,20)
print ("Total: ",principle + result)
# Out:
# Total:  300.0

# %%
type(None)
# Out:
# NoneType

# %%
type("Name")
# Out:
# str

# %%
arr = [1,"giri",3.5,False,["another arr"]]

# %%
len(arr)
# Out:
# 5

# %%
arr[0]
# Out:
# 1

# %%
arr[1]
# Out:
# 'giri'

# %%
arr[2]
# Out:
# 3.5

# %%
arr[3]
# Out:
# False

# %%
arr[4]
# Out:
# ['another arr']

# %%
for e in arr:
    print(e)
    print("Type of ",type(e))
    print(" ")
# Out:
# 1
# Type of  <class 'int'>
#
# giri
# Type of  <class 'str'>
#
# 3.5
# Type of  <class 'float'>
#
# False
# Type of  <class 'bool'>
#
# ['another arr']
# Type of  <class 'list'>

# %%
for e in arr:
    print(e)
    print(f"Type of {e} is",type(e))
   #f is used along with curly bracket to represent the items as below:
# Out:
# 1
# Type of 1 is <class 'int'>
# giri
# Type of giri is <class 'str'>
# 3.5
# Type of 3.5 is <class 'float'>
# False
# Type of False is <class 'bool'>
# ['another arr']
# Type of ['another arr'] is <class 'list'>

# %%
n =10
while n>0:
    print(f"Count down {n}",n)
    n=n-1
# Out:
# Count down 10 10
# Count down 9 9
# Count down 8 8
# Count down 7 7
# Count down 6 6
# Count down 5 5
# Count down 4 4
# Count down 3 3
# Count down 2 2
# Count down 1 1

# %%
# Base 5 to Base 10

num = 1224 # 1*4 + 5*2 + 5*5*2 + 5*5*5*1
result=0
mult=1

# %%
while num>0 :
    rem = num%10
    result = result+rem*mult
    num=num//10
    mult=mult*5
print (result)
# Out:
# 189

# %%
mult,result,num,rem
# Out:
# (625, 189, 0, 1)

# %%
def extract(mult,result,num):
    rem = num%10
    result = result+rem*mult
    num=num//10
    mult=mult*5
    return mult,result,num

# %%
mult,result,num = 1,0,1224
base5num=num

# %%
mult,result,num =extract(mult,result,num)
print(mult,result,num)
# Out:
# 5 4 122

# %%
while num >0:
    mult,result,num =extract(mult,result,num)
print(mult,result,num)
print(f"Base10 value of base5 number {base5num} is ",result)
# Out:
# 625 189 0
# Base10 value of base5 number 1224 is  189

# %%
def extract_rec(tab, mult, result, num):
    print(tab, "Calling: ", mult, result, num)
    rem = num % 10
    result = result + rem*mult
    num = num // 10
    mult = mult * 5
    if num == 0:
        return result
    else:
        fr = extract_rec(tab + "\t", mult, result, num)
        print(tab, "Finished and found: ", fr)
        return fr

# %%
mult, result, num = 1, 0, 100
result = extract_rec("", mult, result, num)
print(result)
# Out:
#  Calling:  1 0 100
# 	 Calling:  5 0 10
# 		 Calling:  25 0 1
# 	 Finished and found:  25
#  Finished and found:  25
# 25

# %%
mult, result, num = 1, 0, 4123324
print(f"Base5 number is {num}")
while num > 0:
    mult, result, num = extract(mult, result, num)
print(f"Base10 value of is {result}")
# Out:
# Base5 number is 4123324
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8de242d48929> in <module>
#       2 print(f"Base5 number is {num}")
#       3 while num > 0:
# ----> 4     mult, result, num = extract(mult, result, num)
#       5 print(f"Base10 value of is {result}")
#
# NameError: name 'extract' is not defined

# %% [markdown]
# ![image.png](attachment:image.png)
