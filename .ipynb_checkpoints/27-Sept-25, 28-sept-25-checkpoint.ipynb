# %% [markdown]
# ## Find Minimum and Maximum of a List
#
# ### Explanation:
#
# When you have a list of numbers, sometimes you want to know the **smallest number** (called the *minimum*) and the **largest number** (called the *maximum*) in that list.
# For example, in the list `[5, 8, 2, 10, 3]`, the smallest number is `2` and the largest number is `10`.
#
# Finding the minimum and maximum is useful in many real-world cases. For example:
#
# * In exam scores, the minimum score shows the lowest marks obtained by a student, and the maximum shows the highest marks.
# * In weather data, the minimum temperature tells the coldest reading of the day, and the maximum shows the hottest reading.
#
# ---
#
# ### Exercise:
#
# Write a function `find_min_max(numbers)` that takes a list of numbers as input and returns a tuple `(minimum, maximum)`.
#
# ---
#
# ### Example:
#
# ```python
# find_min_max([5, 8, 2, 10, 3])
# # Output: (2, 10)
#
# find_min_max([7, 7, 7, 7])
# # Output: (7, 7)
# ```
#
# ---

# %%
def find_min_max(numbers):
    min_value=float('inf')
    max_value=-float('inf')
    for number in numbers:
        if number<min_value:
            min_value=number
        if number>max_value:
            max_value=number
    return min_value,max_value

# %%
find_min_max([5, 8, 2, 10, 3])  
# Output: (2, 10)
# Out:
# (2, 10)

# %%
find_min_max([7, 7, 7, 7])  
# Output: (7, 7)
# Out:
# (7, 7)

# %% [markdown]
# ## Min-Max Normalization
#
# ### Explanation:
#
# When we have numbers that are very different in scale (like exam scores out of 100 and salaries in thousands), it becomes hard to compare them directly.
# **Min-Max Normalization** is a way to rescale numbers so that they fall in a fixed range, usually **0 to 1**.
#
# The formula is:
#
# $$
# \text{normalized value} = \frac{(x - \min)}{(\max - \min)}
# $$
#
# * `x` = the original value
# * `min` = the smallest value in the dataset
# * `max` = the largest value in the dataset
#
# For example, if your dataset is `[10, 20, 30]` and you want to normalize `20`:
#
# $$
# \frac{20 - 10}{30 - 10} = \frac{10}{20} = 0.5
# $$
#
# So the normalized value is **0.5**.
#
# ---
#
# ### Exercise:
#
# Write a function `min_max_normalize(value, data)` that:
#
# * Takes two inputs:
#
#   * `value`: the number you want to normalize
#   * `data`: a list of numbers (dataset)
# * Returns the normalized value of `value` using min-max normalization.
#
# ---
#
# ### Example:
#
# ```python
# min_max_normalize(20, [10, 20, 30])
# # Output: 0.5
#
# min_max_normalize(10, [10, 20, 30])
# # Output: 0.0
# ```
# ---

# %%
def min_max_normalize(value,data):
    min_value,max_value=find_min_max(data)
    normalized_value=(value-min_value)/(max_value-min_value)
    return normalized_value

# %%
min_max_normalize(20, [10, 20, 30])  
# Output: 0.5
# Out:
# 0.5

# %%
min_max_normalize(10, [10, 20, 30])  
# Output: 0.0
# Out:
# 0.0

# %%
# 
[10,9,7,8,5,4,-2,-3,10,11,15]
There is only 1 minima, no two adjacent values aare same.
find the index of the minimum value.
input: [10,9,7,8,5,4,-2,-3,10,11,15]
answer: 6

input: [-1,-2,-8,-20,9,10,30,100]
answer:3
# Out:
#   File "<ipython-input-12-449317d25919>", line 3
#     There is only 1 minima, no two adjacent values aare same.
#                   ^
# SyntaxError: invalid syntax

# %%
f=[-1,-2,-8,-20,9,10,30,100]
def xymini(f):
        
        mid1= (0 + len(f))//2
        midl = mid1-1
        midr = mid1+1
       
        while True:
        
            f1 = f[mid1]
            fl = f[midl]
            fr = f[midr]

            if fl<f1 and fr>f1:
                midl=midl-1
                mid1 = mid1-1
                midr=midr-1
            elif fl>f1 and fr<f1:
                midl=midl+1
                mid1 = mid1+1
                midr=midr+1
            elif f1<fr and fl<f1:
                return midr

            elif f1<fl and fr<f1:
                return midl

            else:
                return mid1

# %%
xymini(f),f[xymini(f)]
# Out:
# 4
# 4
# (3, -20)

# %%
len(f)
# Out:
# 8

# %%
arr=[1,2,3]

# %%
xymini(arr),arr[xymini(arr)]
# Out:
# 3
# 3
# (5, -5)

# %%
arr=[3,2,4,-1,-2,-5,10]

# %%
f=[20,-1,-2,-8,-20,9,10,30,100,10000,20000]
def xymini_rev2(f):
        
        start=0
        end=len(f)
             
        while True:
            
            
            mid1= (start+end)//2
            midl = mid1-1
            midr = mid1+1
            print(f"midl: {midl}, mid1: {mid1}, midr: {midr}")
        
            f1 = f[mid1]
            fl = f[midl]
            fr = f[midr]

            if fl<f1 and fr>f1:
                end=mid1
                
            elif fl>f1 and fr<f1:
                start=mid1
            else:
                return mid1

# %%
xymini_rev2(f)
# Out:
# midl: 4, mid1: 5, midr: 6
# midl: 1, mid1: 2, midr: 3
# midl: 2, mid1: 3, midr: 4
# midl: 3, mid1: 4, midr: 5
# 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def encode_fre(f):
    if len(f)==1:
        bina=[0]
        return bina
    if len(f)==2:
        bina=[0,1]
        return bina
    
    enc=[0]
    num=0
    for i in range(1,len(f)-1):
        num=num+2**i
        enc.append(num)
    enc.append(num+1)
    bina=dectobin2(enc)
    f_sort=sorted(f)
    f_sort=f_sort[::-1]
    return bina,f_sort

# %%
encode_fre([20,20,20,20,20,20,20,20])
# Out:
# ([0, 10, 110, 1110, 11110, 111110, 1111110, 1111111],
#  [20, 20, 20, 20, 20, 20, 20, 20])

# %%
# Write a general algorithm that based on the frequencies, it would come up a design of encoding scheme that 
# represents out input in minimum number of bits and has no confusions

# %%
Input: [90, 5, 5]
Ouput: ["0", "10", "11"]

# %%
Input: [25, 25, 25, 25]
Ouput: ["00", "01", "10", "11"]

# %%
def dectobin2(A):
    binary_list=[]
    for num in A:
        mult=1
        bina=0
        while num!=0:
            bina=num%2*mult+bina
            mult=mult*10
            num=num//2
        binary_list.append(bina)
    return binary_list

# %%
f=[9,4,95]

# %%
f.sort()

# %%
f
# Out:
# [4, 9, 95]

# %%
f.reverse()

# %%
ff
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-97-dcbf514dfbb5> in <module>
# ----> 1 ff
#
# NameError: name 'ff' is not defined

# %%
f
# Out:
# [95, 9, 4]

# %%
f_sort=sorted(f)

# %%
f
# Out:
# [95, 9, 4]

# %%
f_sort
# Out:
# [4, 9, 95]

# %%
dir(f_sort)
# Out:
# ['__bool__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
print(f_sort)
# Out:
# None

# %% [markdown]
# SORTING ALGO

# %%
arr = [1, 3, -1, 5, 3, 10]
def mysorter(arr):
    for i in range(len(arr)):
        min_num=arr[i]
        for j in range(i+1,len(arr)):
            if arr[i]>arr[j]:
                dummy=arr[i]
                dummy2=arr[j]
                arr[i]=dummy2
                arr[j]=dummy
            print(arr)
    return (arr)

# %%
mysorter(arr)
# Out:
# [1, 3, -1, 5, 3, 10]
# [-1, 3, 1, 5, 3, 10]
# [-1, 3, 1, 5, 3, 10]
# [-1, 3, 1, 5, 3, 10]
# [-1, 3, 1, 5, 3, 10]
# [-1, 1, 3, 5, 3, 10]
# [-1, 1, 3, 5, 3, 10]
# [-1, 1, 3, 5, 3, 10]
# [-1, 1, 3, 5, 3, 10]
# [-1, 1, 3, 5, 3, 10]
# [-1, 1, 3, 5, 3, 10]
# [-1, 1, 3, 5, 3, 10]
# [-1, 1, 3, 3, 5, 10]
# [-1, 1, 3, 3, 5, 10]
# [-1, 1, 3, 3, 5, 10]
# [-1, 1, 3, 3, 5, 10]

# %%
#Sorting Tree
class Treesort:
    def __init__(self):
        print("Welcone to Tree Sorter")
        self.num=[]
    def placenumber(self,A):
        if len(self.num)==0:
            self.num.append(A)
        else:
            for i in range(len(self.num)):
                if A < self.num[i]:
                    self.num.insert(i,A)
                    return
                
            self.num.append(A)

# %%
A=Treesort()
# Out:
# Welcone to Tree Sorter

# %%
A.placenumber(2)

# %%
A.num
# Out:
# [2]

# %%
A.placenumber(-1)

# %%
A.num
# Out:
# [-1, 2]

# %%
A.placenumber(8)

# %%
A.num
# Out:
# [-1, 2, 8, 10, 11]

# %%
A=[0,4,6,27,20,49,30,36,6,16]
def bubblesort(A):
    for count in range(len(A)-1):
        for i in range(len(A)-1):
            if A[i]>A[i+1]:
                #print(f"A[i]:{A[i]},A[i+1],{A[i+1]}--->")
                A[i],A[i+1]=A[i+1],A[i]
                #print(f"A[i]:{A[i]},A[i+1],{A[i+1]}")
        print(A)

    return A

# %%
bubblesort(A)
# Out:
# [0, 4, 6, 20, 27, 30, 36, 6, 16, 49]
# [0, 4, 6, 20, 27, 30, 6, 16, 36, 49]
# [0, 4, 6, 20, 27, 6, 16, 30, 36, 49]
# [0, 4, 6, 20, 6, 16, 27, 30, 36, 49]
# [0, 4, 6, 6, 16, 20, 27, 30, 36, 49]
# [0, 4, 6, 6, 16, 20, 27, 30, 36, 49]
# [0, 4, 6, 6, 16, 20, 27, 30, 36, 49]
# [0, 4, 6, 6, 16, 20, 27, 30, 36, 49]
# [0, 4, 6, 6, 16, 20, 27, 30, 36, 49]
# [0, 4, 6, 6, 16, 20, 27, 30, 36, 49]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A=[2,3,4]
high=A[-1]

# %%
high
# Out:
# 4

# %%
#Sorting the sorted list will have n complexity. 
def quicksort(arr):
    if len(arr) <= 1:
        return arr
    else:
        ind=" "
        pivot = arr[0]
        less = [x for x in arr[1:] if x <= pivot]
        greater = [x for x in arr[1:] if x > pivot]
        print(f"{ind} less:{less}, greater: {greater}, pivot{pivot}")
        ind=ind+" "
        return quicksort(less) + [pivot] + quicksort(greater)

A = [0, 15, 24, 27, 27, 28, 29, 29, 36, 50, 51, 52, 66, 70, 85, 87]
sorted_A = quicksort(A)
print("Sorted array:", sorted_A)
# Out:
#   less:[], greater: [15, 24, 27, 27, 28, 29, 29, 36, 50, 51, 52, 66, 70, 85, 87], pivot0
#   less:[], greater: [24, 27, 27, 28, 29, 29, 36, 50, 51, 52, 66, 70, 85, 87], pivot15
#   less:[], greater: [27, 27, 28, 29, 29, 36, 50, 51, 52, 66, 70, 85, 87], pivot24
#   less:[27], greater: [28, 29, 29, 36, 50, 51, 52, 66, 70, 85, 87], pivot27
#   less:[], greater: [29, 29, 36, 50, 51, 52, 66, 70, 85, 87], pivot28
#   less:[29], greater: [36, 50, 51, 52, 66, 70, 85, 87], pivot29
#   less:[], greater: [50, 51, 52, 66, 70, 85, 87], pivot36
#   less:[], greater: [51, 52, 66, 70, 85, 87], pivot50
#   less:[], greater: [52, 66, 70, 85, 87], pivot51
#   less:[], greater: [66, 70, 85, 87], pivot52
#   less:[], greater: [70, 85, 87], pivot66
#   less:[], greater: [85, 87], pivot70
#   less:[], greater: [87], pivot85
# Sorted array: [0, 15, 24, 27, 27, 28, 29, 29, 36, 50, 51, 52, 66, 70, 85, 87]
